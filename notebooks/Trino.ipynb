# %%
from trino import dbapi

conn = dbapi.connect(
    host='10.242.33.226',
    port='30443',
    user='c_ydiakite1',
    #password='Password8*',
    catalog='es_cockpit',
    schema='default'
)

cursor = conn.cursor()

cursor.execute('SELECT * FROM random_commission_fixxe_new_20230104')

results = cursor.fetchall()

cursor.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# BadStatusLine                             Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# ...

# %%
var query_test = """( SELECT * FROM "es_cockpit"."default"."random_commission_fixxe_new_20230104") t """
var test_df = spark 
    .read
    .format("jdbc")
    .option("url", "jdbc:trino://10.242.33.226:30443")
    .option("driver", "io.trino.jdbc.TrinoDriver")
    .option("dbtable", query_test)
    .option("user", "c_ydiakite1")
    .option("password", "Password7*")
    .option("SSL", "true")
    .load()
