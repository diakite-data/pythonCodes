# %%
from linkedin_scraper import Person, actions
from selenium import webdriver
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import pandas_profiling as pp
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re

# %%
#driver = webdriver.Chrome()
#email = "mamadouy@live.fr"
#password = "12090496DMY!"
#actions.login(driver, email, password) # if email and password isnt given, it'll prompt in terminal
#person = Person("https://www.linkedin.com/in/mamadou-youssouf-diakite-083630135/", driver=driver)

# %%
# Site URL
url="https://www.linkedin.com/in/mamadou-youssouf-diakite-083630135/"

# Make a GET request to fetch the raw HTML content
html_content = requests.get(url).text

# Parse HTML code for the entire site
soup = BeautifulSoup(html_content, "lxml")

# %%
soup
# Out:
# <html><head>
# <script type="text/javascript">
# window.onload = function() {
#   // Parse the tracking code from cookies.
#   var trk = "bf";
#   var trkInfo = "bf";
#   var cookies = document.cookie.split("; ");
#   for (var i = 0; i < cookies.length; ++i) {
#     if ((cookies[i].indexOf("trkCode=") == 0) && (cookies[i].length > 8)) {
#       trk = cookies[i].substring(8);
#     }
#     else if ((cookies[i].indexOf("trkInfo=") == 0) && (cookies[i].length > 8)) {
#       trkInfo = cookies[i].substring(8);
#     }
#   }
#
#   if (window.location.protocol == "http:") {
#     // If "sl" cookie is set, redirect to https.
#     for (var i = 0; i < cookies.length; ++i) {
#       if ((cookies[i].indexOf("sl=") == 0) && (cookies[i].length > 3)) {
#         window.location.href = "https:" + window.location.href.substring(window.location.protocol.length);
#         return;
#       }
#     }
#   }
#
#   // Get the new domain. For international domains such as
# ...

# %%
import requests
from time import sleep
from selenium import webdriver
import chromedriver_binary

# %%
driver = webdriver.Chrome()
sleep(5)
driver.maximize_window()
sleep(5)
driver.get("https://www.linkedin.com/")
sleep(5)

# %%
cookies_dict = {}
for cookie in driver.get_cookies():
        cookies_dict[cookie['name']] = cookie['value']
        

driver.close()

# %%
"https://www.linkedin.com/in/mamadou-youssouf-diakite-083630135/"

# %%
resp = requests.get("https://www.linkedin.com/company/twitter",
                     cookies=cookies_dict,
                     headers={'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36',
                              'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
                                                   'accept-encoding': 'gzip, deflate, br',
                                                   'accept-language': 'en-US,en;q=0.9',
                                                   'upgrade-insecure-requests': '1',
                                                   'scheme': 'https'})
        
html = resp.text

# %%
HtmlPath = "D:/linkedin_pages/1.html"
page_fun = open(HtmlPath,'w',encoding='utf-8')
page_fun.write(html)
page_fun.close()

# %%
"careers.twitter.com" in html
# Out:
# True

# %%
resp = requests.get("https://www.linkedin.com/in/mamadou-youssouf-diakite-083630135/",
                     cookies=cookies_dict,
                     headers={'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36',
                              'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
                                                   'accept-encoding': 'gzip, deflate, br',
                                                   'accept-language': 'en-US,en;q=0.9',
                                                   'upgrade-insecure-requests': '1',
                                                   'scheme': 'https'})
        
html = resp.text
html
# Out:
# '<!DOCTYPE html><html lang="en" class="theme theme--mercado"><head>\n    <script type="application/javascript">!function(i,n){void 0!==i.addEventListener&&void 0!==i.hidden&&(n.liVisibilityChangeListener=function(){i.hidden&&(n.liHasWindowHidden=!0)},i.addEventListener("visibilitychange",n.liVisibilityChangeListener))}(document,window);</script>\n\n    <title>LinkedIn</title>\n\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="asset-url" class="mercado-icons-sprite" id="artdeco-icons/static/images/sprite-asset" content="https://static-exp1.licdn.com/sc/h/3ki0iq40x0w1ti93600pfmk84">\n    <meta name="description" content="">\n    <meta name="google" content="notranslate">\n    <meta name="is-http2" content="false">\n    <meta name="service" content="voyager-web">\n    <meta name="theme-color" content="#0077B5">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0">\n    <link rel="manifest" hr
# ...

# %%
#"Jethro" in html

# %%
'0758425075', '0778804873', '0767714230', '0759474769', '0748998856', '0708859231', '0788250476', '0709582140', '0788049224', '0708389694', '0748843295', '0759474769'

# %%
# import web driver
from selenium import webdriver

# specifies the path to the chromedriver.exe
driver = webdriver.Chrome()

# driver.get method() will navigate to a page given by the URL address
driver.get('https://www.linkedin.com/in/mamadou-youssouf-diakite-083630135/')

# %%
# locate email form by_class_name
username = driver.find_element_by_class_name('login-email')
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-27-32df8c071781> in <module>
#       1 # locate email form by_class_name
# ----> 2 username = driver.find_element_by_class_name('login-email')
#
# ~/.local/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_class_name(self, name)
#     562             element = driver.find_element_by_class_name('foo')
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#     566     def find_elements_by_class_name(self, name):
#
# ~/.local/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# ...

# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
df = pd.read_csv("/Users/youssouf/Downloads/DWHDEV_TANGO_CHANNEL_RESTITUTIONS_P10_filtre.csv")
df.head()
# Out:
# /Users/youssouf/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (29,48) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#          USER_NAME              LAST_NAME              LOGIN_ID  \
# 0           Nicole  BONI EPSE GILBERNAIRE  TCP0806130642.000001
# 1        SAN PEDRO            SUPERVISEUR  TCP0806130642.000001
# 2   cit cocody ca1    CIT COCODY CAISSE 1  TCP0811281039.000002
# 3  cit_yopbanco_ca                    CIT  TCP0811281039.000002
# 4     cit_abobo_ca                    CIT  TCP0811281039.000002
#
#           USER_ID     MSISDN  LATITUDE LONGITUDE STATUS  \
# 0  CIAO0000000381  707079056  5,358682   -3,9777     Y
# 1  CIAO0000000922  707090037   4.74666   -6.6554     Y
# 2  CIPT0000149392  707041526   5.33957  -4.00473     Y
# 3  CIPT0000149410  707046897   5.33405  -4.07344     Y
# ...

# %%
df.shape
# Out:
# (43213, 60)

# %%
df.drop_duplicates("MSISDN").shape
# Out:
# (43213, 60)

# %%
df[["USER_NAME", "USER_GRADE", "GRADE_NAME"]].head()
# Out:
#          USER_NAME                 USER_GRADE                 GRADE_NAME
# 0           Nicole  Agence Orange Distributor  Agence Orange Distributor
# 1        SAN PEDRO  Agence Orange Distributor  Agence Orange Distributor
# 2   cit cocody ca1            Grossiste 1 PDV            Grossiste 1 PDV
# 3  cit_yopbanco_ca            Grossiste 1 PDV            Grossiste 1 PDV
# 4     cit_abobo_ca            Grossiste 1 PDV            Grossiste 1 PDV

# %%
np.unique(df["STATUS"].values, return_counts = True)
# Out:
# (array(['S', 'S ', 'Y', 'Y '], dtype=object),
#  array([ 1143,    93, 24725, 17252]))
