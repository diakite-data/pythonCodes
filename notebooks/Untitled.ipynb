# %%
import pandas as pd

# %%
prod_simbox_profil = pd.read_csv("/Users/youssouf/Downloads/prod_simbox_profil.csv", sep = ";")

# %%
pp = prod_simbox_profil.columns.to_list()
pp
# Out:
# ['prod_simbox_profil.date_id',
#  'prod_simbox_profil.msisdn',
#  'prod_simbox_profil.nbr_dist_profil']

# %%
pp_dict = {i.split(".")[0]:i.split(".")[1] for i in pp}
pp_dict
# Out:
# {'prod_simbox_profil': 'nbr_dist_profil'}

# %%
[i.split(".")[1] for i in pp]
# Out:
# ['date_id', 'msisdn', 'nbr_dist_profil']

# %%
for i in pp :
    print(i.split(".")[1])
# Out:
# date_id
# msisdn
# nbr_dist_profil

# %%
gg = {0: 0.0044, 1: 0.1633, 2: 0.043, 3: 0.0428, 4: 0.0131, 5: 0.0006, 6: 0.0963, 7: 0.0302, 8: 0.0045, 9: 0.0001, 10: 0.0202, 11: 0.0012, 12: 0.0032, 13: 0.0025, 14: 0.0021, 15: 0.006, 16: 0.0194, 17: 0.0322, 18: 0.0131, 19: 0.0001, 20: 0.0386, 21: 0.0307, 22: 0.0244, 23: 0.0484, 24: 0.0007, 26: 0.0001, 27: 0.0001, 28: 0.0149, 29: 0.0003, 30: 0.0062, 31: 0.0126, 32: 0.0002, 33: 0.0002, 34: 0.0072, 35: 0.0113, 36: 0.0002, 37: 0.0114, 38: 0.0138, 39: 0.0192, 40: 0.0264, 41: 0.0014, 42: 0.0016, 43: 0.0139, 45: 0.0109, 46: 0.0026, 47: 0.0003, 48: 0.0336, 49: 0.0003, 50: 0.0006, 51: 0.0024, 52: 0.0837, 53: 0.0067, 54: 0.0001, 55: 0.0003, 56: 0.0176, 57: 0.0008, 58: 0.0037, 59: 0.0435, 61: 0.0023, 62: 0.0086}

# %%
ff = ["dure_call_moy_inter", "duree_call_moy_en", "duree_call_moy_inter_en",
  "duree_call_moy_sort", "duree_call_sort_moy_of", "duree_call_sort_moy_on", "duree_call_tot_en",
  "duree_call_tot_sort" , "duree_moy_call_complice", "duree_moy_sort_night", "ecartyp_temp_appel" ,
  "ecartyp_temp_sms","mnt_emprunt_tot_sos", "mnt_med_data","mnt_med_inter", "mnt_med_mix", "mnt_med_sva",
  "mnt_rechar_tot", "nbr_achat_pass_data", "nbr_achat_pass_inter", "nbr_achat_pass_mix", "nbr_achat_pass_sva",
  "nbr_appel_inter", "nbr_call_dist_call", "nbr_call_en_abs", "nbr_call_inter_tot_en", "nbr_call_sort_abs",
  "nbr_call_sort_night", "nbr_call_sort_of", "nbr_call_sort_on", "nbr_call_tot_complice", "nbr_call_tot_en",
  "nbr_dist_abs_en", "nbr_dist_abs_sort", "nbr_dist_call_complice", "nbr_dist_call_en", "nbr_dist_call_sort_night",
  "nbr_dist_inter_en", "nbr_dist_profil", "nbr_dist_sms_en", "nbr_dist_sort_of", "nbr_dist_sort_on",
  "nbr_emprunt_sos", "nbr_rechar", "nbr_sms_inter", "nbr_sms_sort", "nbr_sms_sort_of", "nbr_sms_sort_on",
  "nbr_tot_call", "nbr_tot_rechar_om", "nbr_tot_transact_om_receiv", "nbr_tot_transact_om_send",
  "nbre_distinct_imei", "nbre_imsi", "rechar_om_med", "rechar_om_tot", "temp_appel_moy", "temp_sms_moy",
  "transact_om_med_receiv", "statut_activite", "statut_om", "transact_om_med_send", "vol_data_conso"]

# %%
pd.DataFrame(dict(zip(ff , list(gg.values()))), index = range(len(ff)))
# Out:
#     dure_call_moy_inter  duree_call_moy_en  duree_call_moy_inter_en  \
# 0                0.0044             0.1633                    0.043
# 1                0.0044             0.1633                    0.043
# 2                0.0044             0.1633                    0.043
# 3                0.0044             0.1633                    0.043
# 4                0.0044             0.1633                    0.043
# ..                  ...                ...                      ...
# 58               0.0044             0.1633                    0.043
# 59               0.0044             0.1633                    0.043
# 60               0.0044             0.1633                    0.043
# 61               0.0044             0.1633                    0.043
# 62               0.0044             0.1633                    0.043
#
#     duree_call_moy_sort  duree_call_sort_moy_of  duree_call_sort_moy_on  \
# 0                0.0428                  0.0131                  0.0006
# ...

# %%
dict(zip(ff , list(gg.values())))
# Out:
# {'dure_call_moy_inter': 0.0044,
#  'duree_call_moy_en': 0.1633,
#  'duree_call_moy_inter_en': 0.043,
#  'duree_call_moy_sort': 0.0428,
#  'duree_call_sort_moy_of': 0.0131,
#  'duree_call_sort_moy_on': 0.0006,
#  'duree_call_tot_en': 0.0963,
#  'duree_call_tot_sort': 0.0302,
#  'duree_moy_call_complice': 0.0045,
#  'duree_moy_sort_night': 0.0001,
#  'ecartyp_temp_appel': 0.0202,
#  'ecartyp_temp_sms': 0.0012,
#  'mnt_emprunt_tot_sos': 0.0032,
#  'mnt_med_data': 0.0025,
#  'mnt_med_inter': 0.0021,
#  'mnt_med_mix': 0.006,
#  'mnt_med_sva': 0.0194,
#  'mnt_rechar_tot': 0.0322,
#  'nbr_achat_pass_data': 0.0131,
#  'nbr_achat_pass_inter': 0.0001,
#  'nbr_achat_pass_mix': 0.0386,
#  'nbr_achat_pass_sva': 0.0307,
#  'nbr_appel_inter': 0.0244,
#  'nbr_call_dist_call': 0.0484,
#  'nbr_call_en_abs': 0.0007,
#  'nbr_call_inter_tot_en': 0.0001,
#  'nbr_call_sort_abs': 0.0001,
#  'nbr_call_sort_night': 0.0149,
#  'nbr_call_sort_of': 0.0003,
#  'nbr_call_sort_on': 0.0062,
# ...

# %%
df_prediction_rf %>% mutate(property5 = map(prediction_rf.probability , fromJSON)) %>%
    unnest_wider(col = property5)
